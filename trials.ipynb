# %%
from langchain import PromptTemplate
from langchain.chains import RetrievalQA
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Pinecone
import pinecone
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.prompts import PromptTemplate
from langchain.llms import CTransformers
from tqdm.autonotebook import tqdm

# %%
PINECONE_API_KEY = "pcsk_4g1Dfq_FDUse6ffwK2XZTqypEFiuALCCoUuPAiaec1GRqrWiAoVHHLaEiijNMdCPb4znGp"
PINECONE_API_ENV = "gcp-starter"

# %%
def load_pdf(data):
    loader = DirectoryLoader(data,
                    glob="*.pdf",
                    loader_cls=PyPDFLoader)
    
    documents = loader.load()

    return documents

# %%
extracted_data = load_pdf("data/")
extracted_data
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 extracted_data = load_pdf("data/")
#       2 extracted_data
#
# Cell In[5], line 6, in load_pdf(data)
#       1 def load_pdf(data):
#       2     loader = DirectoryLoader(data,
#       3                     glob="*.pdf",
#       4                     loader_cls=PyPDFLoader)
# ----> 6     documents = loader.load()
#       8     return documents
#
# File c:\Users\Admin\.vscode\A3\envs\mchatbot\lib\site-packages\langchain_community\document_loaders\directory.py:117, in DirectoryLoader.load(self)
#     115 def load(self) -> List[Document]:
#     116     """Load documents."""
# --> 117     return list(self.lazy_load())
#
# File c:\Users\Admin\.vscode\A3\envs\mchatbot\lib\site-packages\langchain_community\document_loaders\directory.py:195, in DirectoryLoader.lazy_load(self)
#     193 else:
#     194     for i in items:
# --> 195         yield from self._lazy_load_file(i, p, pbar)
#     197 if pbar:
#     198     pbar.close()
#
# File c:\Users\Admin\.vscode\A3\envs\mchatbot\lib\site-packages\langchain_community\document_loaders\directory.py:223, in DirectoryLoader._lazy_load_file(self, item, path, pbar)
#     221 loader = self.loader_cls(str(item), **self.loader_kwargs)
#     222 try:
# --> 223     for subdoc in loader.lazy_load():
#     224         yield subdoc
#     225 except NotImplementedError:
#
# File c:\Users\Admin\.vscode\A3\envs\mchatbot\lib\site-packages\langchain_community\document_loaders\pdf.py:257, in PyPDFLoader.lazy_load(self)
#     255 else:
#     256     blob = Blob.from_path(self.file_path)  # type: ignore[attr-defined]
# --> 257 yield from self.parser.parse(blob)
#
# File c:\Users\Admin\.vscode\A3\envs\mchatbot\lib\site-packages\langchain_core\document_loaders\base.py:126, in BaseBlobParser.parse(self, blob)
#     111 def parse(self, blob: Blob) -> List[Document]:
#     112     """Eagerly parse the blob into a document or documents.
#     113
#     114     This is a convenience method for interactive development environment.
#    (...)
#     124         List of documents
#     125     """
# --> 126     return list(self.lazy_parse(blob))
#
# File c:\Users\Admin\.vscode\A3\envs\mchatbot\lib\site-packages\langchain_community\document_loaders\parsers\pdf.py:124, in PyPDFParser.lazy_parse(self, blob)
#     121 with blob.as_bytes_io() as pdf_file_obj:  # type: ignore[attr-defined]
#     122     pdf_reader = pypdf.PdfReader(pdf_file_obj, password=self.password)
# --> 124     yield from [
#     125         Document(
#     126             page_content=_extract_text_from_page(page=page)
#     127             + self._extract_images_from_page(page),
#     128             metadata={"source": blob.source, "page": page_number},  # type: ignore[attr-defined]
#     129         )
#     130         for page_number, page in enumerate(pdf_reader.pages)
#     131     ]
#
# File c:\Users\Admin\.vscode\A3\envs\mchatbot\lib\site-packages\langchain_community\document_loaders\parsers\pdf.py:126, in <listcomp>(.0)
#     121 with blob.as_bytes_io() as pdf_file_obj:  # type: ignore[attr-defined]
#     122     pdf_reader = pypdf.PdfReader(pdf_file_obj, password=self.password)
#     124     yield from [
#     125         Document(
# --> 126             page_content=_extract_text_from_page(page=page)
#     127             + self._extract_images_from_page(page),
#     128             metadata={"source": blob.source, "page": page_number},  # type: ignore[attr-defined]
#     129         )
#     130         for page_number, page in enumerate(pdf_reader.pages)
#     131     ]
#
# File c:\Users\Admin\.vscode\A3\envs\mchatbot\lib\site-packages\langchain_community\document_loaders\parsers\pdf.py:117, in PyPDFParser.lazy_parse.<locals>._extract_text_from_page(page)
#     115     return page.extract_text()
#     116 else:
# --> 117     return page.extract_text(
#     118         extraction_mode=self.extraction_mode, **self.extraction_kwargs
#     119     )
#
# File c:\Users\Admin\.vscode\A3\envs\mchatbot\lib\site-packages\pypdf\_page.py:2393, in PageObject.extract_text(self, orientations, space_width, visitor_operand_before, visitor_operand_after, visitor_text, extraction_mode, *args, **kwargs)
#    2390 if isinstance(orientations, int):
#    2391     orientations = (orientations,)
# -> 2393 return self._extract_text(
#    2394     self,
#    2395     self.pdf,
#    2396     orientations,
#    2397     space_width,
#    2398     PG.CONTENTS,
#    2399     visitor_operand_before,
#    2400     visitor_operand_after,
#    2401     visitor_text,
#    2402 )
#
# File c:\Users\Admin\.vscode\A3\envs\mchatbot\lib\site-packages\pypdf\_page.py:2136, in PageObject._extract_text(self, obj, pdf, orientations, space_width, content_key, visitor_operand_before, visitor_operand_after, visitor_text)
#    2134 xobj = resources_dict["/XObject"]
#    2135 if xobj[operands[0]]["/Subtype"] != "/Image":  # type: ignore
# -> 2136     text = self.extract_xform_text(
#    2137         xobj[operands[0]],  # type: ignore
#    2138         orientations,
#    2139         space_width,
#    2140         visitor_operand_before,
#    2141         visitor_operand_after,
#    2142         visitor_text,
#    2143     )
#    2144     output += text
#    2145     if visitor_text is not None:
#
# File c:\Users\Admin\.vscode\A3\envs\mchatbot\lib\site-packages\pypdf\_page.py:2428, in PageObject.extract_xform_text(self, xform, orientations, space_width, visitor_operand_before, visitor_operand_after, visitor_text)
#    2404 def extract_xform_text(
#    2405     self,
#    2406     xform: EncodedStreamObject,
#    (...)
#    2411     visitor_text: Optional[Callable[[Any, Any, Any, Any, Any], None]] = None,
#    2412 ) -> str:
#    2413     """
#    2414     Extract text from an XObject.
#    2415
#    (...)
#    2426
#    2427     """
# -> 2428     return self._extract_text(
#    2429         xform,
#    2430         self.pdf,
#    2431         orientations,
#    2432         space_width,
#    2433         None,
#    2434         visitor_operand_before,
#    2435         visitor_operand_after,
#    2436         visitor_text,
#    2437     )
#
# File c:\Users\Admin\.vscode\A3\envs\mchatbot\lib\site-packages\pypdf\_page.py:2089, in PageObject._extract_text(self, obj, pdf, orientations, space_width, content_key, visitor_operand_before, visitor_operand_after, visitor_text)
#    2086         except OrientationNotFoundError:
#    2087             return None
# -> 2089 for operands, operator in content.operations:
#    2090     if visitor_operand_before is not None:
#    2091         visitor_operand_before(operator, operands, cm_matrix, tm_matrix)
#
# File c:\Users\Admin\.vscode\A3\envs\mchatbot\lib\site-packages\pypdf\generic\_data_structures.py:1404, in ContentStream.operations(self)
#    1401 @property
#    1402 def operations(self) -> List[Tuple[Any, Any]]:
#    1403     if not self._operations and self._data:
# -> 1404         self._parse_content_stream(BytesIO(self._data))
#    1405         self._data = b""
#    1406     return self._operations
#
# File c:\Users\Admin\.vscode\A3\envs\mchatbot\lib\site-packages\pypdf\generic\_data_structures.py:1290, in ContentStream._parse_content_stream(self, stream)
#    1288     break
#    1289 stream.seek(-1, 1)
# -> 1290 if peek.isalpha() or peek in (b"'", b'"'):
#    1291     operator = read_until_regex(stream, NameObject.delimiter_pattern)
#    1292     if operator == b"BI":
#    1293         # begin inline image - a completely different parsing
#    1294         # mechanism is required, of course... thanks buddy...
#
# KeyboardInterrupt:
